# %% [markdown]
# # EDA

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing the data

# %%
data = pd.read_csv('imbalanced_data.csv')
data.head()
# Out:
#   Diagnosis     ID  Imaginary Part: Min  Imaginary Part: Avg  Real Part: Min  \
# 0      COPD  301-4              -320.61          -300.563531         -495.26
# 1      COPD  302-3              -325.39          -314.750360         -473.73
# 2      COPD  303-3              -323.00          -317.436056         -476.12
# 3      COPD  304-4              -327.78          -317.399670         -473.73
# 4      COPD  305-4              -325.39          -316.155785         -478.52
#
#    Real Part: Avg  Gender   Age  Smoking
# 0     -464.171991     1.0  77.0      2.0
# 1     -469.263140     0.0  72.0      2.0
# 2     -471.897667     1.0  73.0      3.0
# 3     -468.856388     1.0  76.0      2.0
# 4     -472.869783     0.0  65.0      2.0

# %%
data['Diagnosis'] = data['Diagnosis'].astype('object')

# %% [markdown]
# # Exploring the data

# %%
sns.countplot(data, x = 'Diagnosis')
# Out:
# <Axes: xlabel='Diagnosis', ylabel='count'>

# %% [markdown]
# Majority of paitents have COPD or are parts of Healthy control groups, data is imbalanced

# %%
sns.countplot(data, x = 'Diagnosis', hue = 'Gender')
# Out:
# <Axes: xlabel='Diagnosis', ylabel='count'>

# %% [markdown]
# More Female paitents have Asthma and Infections then males

# %%
sns.countplot(data, x = 'Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# As always majority of paitents are males

# %%
sns.countplot(data, x = 'Smoking')
# Out:
# <Axes: xlabel='Smoking', ylabel='count'>

# %% [markdown]
# Most paitients are ex-smokers and non smokers, a few active smokers.

# %%
data['Age'] = data['Age'].astype('float64')

# %%
sns.distplot(data['Age'])
# Out:
# C:\Users\jayth\AppData\Local\Temp\ipykernel_4076\2317092479.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# All paitents are adults, ranging from young adults in the 20's to senior citizens upto their late seventies, very few paitents in their eighties and beyond

# %%
sns.countplot(data, x = 'Smoking',hue='Gender')
# Out:
# <Axes: xlabel='Smoking', ylabel='count'>

# %%
# Disease by non smokers
sns.countplot(data, x='Smoking',hue='Diagnosis' )
# Out:
# <Axes: xlabel='Smoking', ylabel='count'>

# %% [markdown]
# Non-Smokers:
# most are healthy, rest have infections and asthma, very few with COPD
#
# Ex-Smokers:
# Majority have COPD.
#
# Active Smokers:
# Not cases with infections, most are healthy with few having asthama and COPD

# %%
# Disease by non smokers
sns.boxplot(data, y='Age',x='Diagnosis')
# Out:
# <Axes: xlabel='Diagnosis', ylabel='Age'>

# %% [markdown]
# COPD:
# Seen mostly in middle aged to senior citizens
#
# Asthama:
# Obsevered across almost all age groups
#
# Infections:
# Not seen in older paients beyond 50-55
#
# Healthy Groups:
# Oldest paients are upto the age of 60/65

# %%
sns.distplot(data['Imaginary Part: Min'])
# Out:
# C:\Users\jayth\AppData\Local\Temp\ipykernel_4076\52881392.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Imaginary Part: Min'])
# <Axes: xlabel='Imaginary Part: Min', ylabel='Density'>

# %%
sns.distplot(data['Imaginary Part: Avg'])
# Out:
# C:\Users\jayth\AppData\Local\Temp\ipykernel_4076\3035239332.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Imaginary Part: Avg'])
# <Axes: xlabel='Imaginary Part: Avg', ylabel='Density'>

# %%
sns.distplot(data['Real Part: Min'])
# Out:
# C:\Users\jayth\AppData\Local\Temp\ipykernel_4076\2266557487.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Real Part: Min'])
# <Axes: xlabel='Real Part: Min', ylabel='Density'>

# %%
sns.distplot(data['Real Part: Avg'])
# Out:
# C:\Users\jayth\AppData\Local\Temp\ipykernel_4076\1891570603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Real Part: Avg'])
# <Axes: xlabel='Real Part: Avg', ylabel='Density'>

# %% [markdown]
# Imaginary part and real part data has a wide distribution with outlier values

# %%
sns.heatmap(data.corr())
# Out:
# C:\Users\jayth\AppData\Local\Temp\ipykernel_4076\1794321463.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <Axes: >
